# %%
import pygrab
import numba

# %%
params = {
    'name': 'hey'  # Example value for x
}

# %%
pygrab.get("http://127.0.0.1:8000/33", params=params).json()
# Out:
# {'data': 'some json data -> 33'}
